# %%
from transformation import *

ex = tf_tree()
ex.save_load_tree('load','test')
ex.print_tree(1)
# Out:
# 1
# ├── 2 logarithm
# │   └── 3 split_models
# │       └── 4 create_train
# │           └── 5 forecast
# │               └── 6 plot
# ├── 7 split_models
# │   └── 8 create_train
# │       └── 9 forecast
# │           └── 10 plot
# └── 15 scaling
#     └── 11 split_models
#         └── 12 create_train
#             └── 13 forecast
#                 └── 14 plot

# %%
ex.exec_tree()
# Out:
# True
