# %%
from transformation import *

test = tf_tree()
address = '/Users/hyojaeshin/Desktop/CIS422/Project1/cis422-project1/timeSeriesData2/AtmPres2005NovMin.csv'
test.create_tree(address)
test.add_operator(1, "logarithm")
test.add_operator(2, "split_models")
test.add_operator(3, "create_train")
test.add_operator(4, "forecast")
test.add_operator(5, "plot")
test.print_tree(1)
# Out:
# Training % : .5
# Valid % : .3
# Test % : .2
# Enter Layers ly1 ly2 ly3 : 20 20 20
# Enter number of inputs (mi): 4
# Enter number of input spacing (ti): 2
# Enter number of outputs (mo): 1
# Enter number of output spacing (to): 1
# Enter number of forecasts : 3000
# Enter base for forecasts (Valid | Test): valid
# 1
# └── 2 logarithm
#     └── 3 split_models
#         └── 4 create_train
#             └── 5 forecast
#                 └── 6 plot

# %%
test.exec_tree()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-712fbf7476ef> in <module>
# ----> 1 test.exec_tree()
#
# ~/Desktop/CIS422/Project1/cis422-project1/transformation.py in exec_tree(self)
#     202                 if self.root.leaves:
#     203                         for leaf in self.root.leaves:
# --> 204                                 self.results[int(leaf.name)] = self.exec_pipeline(leaf.name)
#     205                         return True
#     206                 else:
#
# ~/Desktop/CIS422/Project1/cis422-project1/transformation.py in exec_pipeline(self, node)
#     221                                 if not pl.is_root and pl.operator:
#     222                                         pl.data = copy.deepcopy(pl.parent.data)
# --> 223                                         pl.data = operations.pick_operator(pl)
#     224                         return pl.data
#     225                 else:
#
# ~/Desktop/CIS422/Project1/cis422-project1/operations.py in pick_operator(node)
#      97                 traindf = data[0]
#      98                 train_x, train_y = preprocessing.design_matrix(traindf, node.mt[0], node.mt[1], node.mt[2], node.mt[3])
# ---> 99                 node.model.fit(train_x, train_y)
#     100                 return data
#     101         elif op == 'forecast':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py in fit(self, X, y)
#     639         self : returns a trained MLP model.
#     640         """
# --> 641         return self._fit(X, y, incremental=False)
#     642
#     643     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     320         # Validate input parameters.
#     321         self._validate_hyperparameters()
# --> 322         if np.any(np.array(hidden_layer_sizes) <= 0):
#     323             raise ValueError("hidden_layer_sizes must be > 0, got %s." %
#     324                              hidden_layer_sizes)
#
# TypeError: '<=' not supported between instances of 'numpy.ndarray' and 'int'

# %%
copy = test.replicate_subtree(3)

test.add_subtree(copy, 1)

test.print_tree(1)
# Out:
# 1
# ├── 2 logarithm
# │   └── 3 split_models
# │       └── 4 create_train
# │           └── 5 forecast
# │               └── 6 plot
# └── 7 split_models
#     └── 8 create_train
#         └── 9 forecast
#             └── 10 plot

# %%
copy = test.replicate_subtree(3)
test.add_operator(1, 'scaling')
test.add_subtree(copy, 15)
test.print_tree(1)
# Out:
# 1
# ├── 2 logarithm
# │   └── 3 split_models
# │       └── 4 create_train
# │           └── 5 forecast
# │               └── 6 plot
# ├── 7 split_models
# │   └── 8 create_train
# │       └── 9 forecast
# │           └── 10 plot
# └── 15 scaling
#     └── 11 split_models
#         └── 12 create_train
#             └── 13 forecast
#                 └── 14 plot

# %%
test.exec_tree()
# Out:
# True

# %%
test.save_load_tree('save', 'test')
