# %%
from preprocessing import *
import pandas as pd
from datetime import datetime

# %%
df = read("./timeSeriesData/1_temperature_test.csv")

# %%
df2 = read("./timeSeriesData2/AtmPres2005NovMin.csv")

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot(x=0, y=1)
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
difference(df2)

# %%
df2.tail(5)
# Out:
#                  Datetime  Station Pressure [mBar]
# 44635 2005-12-01 23:55:00                     0.03
# 44636 2005-12-01 23:56:00                     0.09
# 44637 2005-12-01 23:57:00                    -0.04
# 44638 2005-12-01 23:58:00                     0.05
# 44639 2005-12-01 23:59:00                     0.04

# %%
df2.plot(x=0, y=1)
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
if "Datetime" not in df2:
    print("hey")
else:
    print("not")
# Out:
# not

# %%
assign_time(df, 50, 20)

# %%
df.tail(30)
# Out:
#                Datetime  Time Series
# 114 2010-01-01 00:38:50         26.1
# 115 2010-01-01 00:39:10         26.1
# 116 2010-01-01 00:39:30         26.8
# 117 2010-01-01 00:39:50         26.7
# 118 2010-01-01 00:40:10         27.1
# 119 2010-01-01 00:40:30         27.3
# 120 2010-01-01 00:40:50         27.1
# 121 2010-01-01 00:41:10         26.8
# 122 2010-01-01 00:41:30         26.7
# 123 2010-01-01 00:41:50         27.2
# 124 2010-01-01 00:42:10         27.4
# 125 2010-01-01 00:42:30         27.2
# 126 2010-01-01 00:42:50         27.2
# 127 2010-01-01 00:43:10         27.7
# 128 2010-01-01 00:43:30         27.9
# 129 2010-01-01 00:43:50         27.9
# 130 2010-01-01 00:44:10         27.9
# 131 2010-01-01 00:44:30         28.1
# 132 2010-01-01 00:44:50         28.6
# 133 2010-01-01 00:45:10         28.3
# 134 2010-01-01 00:45:30         27.8
# 135 2010-01-01 00:45:50         28.0
# 136 2010-01-01 00:46:10         28.2
# 137 2010-01-01 00:46:30         28.2
# 138 2010-01-01 00:46:50         27.8
# 139 2010-01-01 00:47:10         27.7
# 140 2010-01-01 00:47:30         27.5
# 141 2010-01-01 00:47:50         27.4
# 142 2010-01-01 00:48:10         27.4
# 143 2010-01-01 00:48:30         26.7
