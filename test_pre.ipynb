# %%
from preprocessing import *
import pandas as pd
from datetime import datetime
import numpy as np

# %%
df = read("./timeSeriesData/8_distribution_subsampled_test.csv")

# %%
df2 = read("./timeSeriesData2/wind_corrales_10m_complete.csv")

# %%
df.iloc[3, -1:] = 3500
df.iloc[33, -1:] = 7
df.iloc[93, -1:] = 4
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = impute_outliers(df)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = longest_continuous_run(df)

# %%
df.iloc[:,:]
# Out:
#      Time Series
# 0        3011.09
# 1        2863.64
# 2        2890.41
# 3        2500.00
# 4        2595.85
# ..           ...
# 163      3394.81
# 164      3429.82
# 165      3408.10
# 166      2839.54
# 167      2751.37
#
# [168 rows x 1 columns]

# %%
df2.head()
# Out:
#              Datetime   3.7
# 0 2007-01-19 15:00:00   5.5
# 1 2007-01-19 16:00:00   6.0
# 2 2007-01-19 17:00:00   6.6
# 3 2007-01-19 18:00:00   4.8
# 4 2007-01-19 19:00:00   6.7

# %%
df2.plot(x=0, y=1)
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
difference(df2)
# Out:
#                  Datetime   3.7
# 0     2007-01-19 15:00:00   NaN
# 1     2007-01-19 16:00:00   0.5
# 2     2007-01-19 17:00:00   0.6
# 3     2007-01-19 18:00:00  -1.8
# 4     2007-01-19 19:00:00   1.9
# ...                   ...   ...
# 43372 2011-12-31 19:00:00   1.5
# 43373 2011-12-31 20:00:00  -0.9
# 43374 2011-12-31 21:00:00   2.4
# 43375 2011-12-31 22:00:00  -0.9
# 43376 2011-12-31 23:00:00   0.1
#
# [43377 rows x 2 columns]

# %%
df2.head(5)
# Out:
#              Datetime   3.7
# 0 2007-01-19 15:00:00   5.5
# 1 2007-01-19 16:00:00   6.0
# 2 2007-01-19 17:00:00   6.6
# 3 2007-01-19 18:00:00   4.8
# 4 2007-01-19 19:00:00   6.7

# %%
df2.plot(x=0, y=1)
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
if "Datetime" not in df2:
    print("hey")
else:
    print("not")
# Out:
# not

# %%
assign_time(df, 50, 20)
# Out:
#                Datetime  Time Series
# 0   2010-01-01 00:00:50      3011.09
# 1   2010-01-01 00:01:10      2863.64
# 2   2010-01-01 00:01:30      2890.41
# 3   2010-01-01 00:01:50      2500.00
# 4   2010-01-01 00:02:10      2595.85
# ..                  ...          ...
# 163 2010-01-01 00:55:10      3394.81
# 164 2010-01-01 00:55:30      3429.82
# 165 2010-01-01 00:55:50      3408.10
# 166 2010-01-01 00:56:10      2839.54
# 167 2010-01-01 00:56:30      2751.37
#
# [168 rows x 2 columns]

# %%
df2.head()
# Out:
#              Datetime   3.7
# 0 2007-01-19 15:00:00   5.5
# 1 2007-01-19 16:00:00   6.0
# 2 2007-01-19 17:00:00   6.6
# 3 2007-01-19 18:00:00   4.8
# 4 2007-01-19 19:00:00   6.7

# %%
impute_missing_data(df2)
# Out:
#                  Datetime   3.7
# 0     2007-01-19 15:00:00   5.5
# 1     2007-01-19 16:00:00   6.0
# 2     2007-01-19 17:00:00   6.6
# 3     2007-01-19 18:00:00   4.8
# 4     2007-01-19 19:00:00   6.7
# ...                   ...   ...
# 43372 2011-12-31 19:00:00   6.1
# 43373 2011-12-31 20:00:00   5.2
# 43374 2011-12-31 21:00:00   7.6
# 43375 2011-12-31 22:00:00   6.7
# 43376 2011-12-31 23:00:00   6.8
#
# [43377 rows x 2 columns]

# %%
df2.head()
# Out:
#              Datetime   3.7
# 0 2007-01-19 15:00:00   5.5
# 1 2007-01-19 16:00:00   6.0
# 2 2007-01-19 17:00:00   6.6
# 3 2007-01-19 18:00:00   4.8
# 4 2007-01-19 19:00:00   6.7

# %%
df2.plot(x=0, y=1)
# Out:
# <AxesSubplot:xlabel='Datetime'>
